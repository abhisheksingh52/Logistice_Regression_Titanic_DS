# %%
import pandas as pd
import numpy as np
titanic_ds=pd.read_csv("train.csv")

# %%
titanic_ds['is_Cabin']=np.where(titanic_ds['Cabin'].isnull(),0,1)

# %%
titanic_ds['Age']=titanic_ds['Age'].fillna(titanic_ds['Age'].median())

# %%
titanic_ds['Embarked']=titanic_ds['Embarked'].fillna('C')

# %%
titanic_ds['Age']=np.where(titanic_ds['Age']>titanic_ds.Age.quantile(0.98),titanic_ds.Age.quantile(0.98),titanic_ds['Age'])

# %%
titanic_ds['Fare']=np.where(titanic_ds['Fare']>titanic_ds.Fare.quantile(0.98),titanic_ds.Fare.quantile(0.98),titanic_ds['Fare'])

# %%
titanic_ds['fg_Pclass_1']=np.where(titanic_ds['Pclass']==1,1,0)

# %%
titanic_ds[['fg_Pclass_1','Pclass']]
# Out:
#      fg_Pclass_1  Pclass
# 0              0       3
# 1              1       1
# 2              0       3
# 3              1       1
# 4              0       3
# 5              0       3
# 6              1       1
# 7              0       3
# 8              0       3
# 9              0       2
# 10             0       3
# 11             1       1
# 12             0       3
# 13             0       3
# 14             0       3
# 15             0       2
# 16             0       3
# 17             0       2
# 18             0       3
# 19             0       3
# 20             0       2
# 21             0       2
# 22             0       3
# 23             1       1
# 24             0       3
# 25             0       3
# 26             0       3
# 27             1       1
# 28             0       3
# 29             0       3
# ..           ...     ...
# 861            0       2
# 862            1       1
# 863            0       3
# 864            0       2
# 865            0       2
# ...

# %%
titanic_ds['fg_Pclass_2']=np.where(titanic_ds['Pclass']==2,1,0)

# %%
titanic_ds[['fg_Pclass_1','fg_Pclass_2','Pclass']]
# Out:
#      fg_Pclass_1  fg_Pclass_2  Pclass
# 0              0            0       3
# 1              1            0       1
# 2              0            0       3
# 3              1            0       1
# 4              0            0       3
# 5              0            0       3
# 6              1            0       1
# 7              0            0       3
# 8              0            0       3
# 9              0            1       2
# 10             0            0       3
# 11             1            0       1
# 12             0            0       3
# 13             0            0       3
# 14             0            0       3
# 15             0            1       2
# 16             0            0       3
# 17             0            1       2
# 18             0            0       3
# 19             0            0       3
# 20             0            1       2
# 21             0            1       2
# 22             0            0       3
# 23             1            0       1
# ...

# %%
titanic_ds['fg_Sex_M']=np.where(titanic_ds['Sex'] == 'male',1,0)

# %%
titanic_ds[['fg_Sex_M','Sex']]
# Out:
#      fg_Sex_M     Sex
# 0           1    male
# 1           0  female
# 2           0  female
# 3           0  female
# 4           1    male
# 5           1    male
# 6           1    male
# 7           1    male
# 8           0  female
# 9           0  female
# 10          0  female
# 11          0  female
# 12          1    male
# 13          1    male
# 14          0  female
# 15          0  female
# 16          1    male
# 17          1    male
# 18          0  female
# 19          0  female
# 20          1    male
# 21          1    male
# 22          0  female
# 23          1    male
# 24          0  female
# 25          0  female
# 26          1    male
# 27          1    male
# 28          0  female
# 29          1    male
# ..        ...     ...
# 861         1    male
# 862         0  female
# 863         0  female
# 864         1    male
# 865         0  female
# 866         0  female
# 867         1    male
# 868         1    male
# 869         1    male
# ...

# %%
titanic_ds['fg_Embark_S']=np.where(titanic_ds['Embarked'] == 'S',1,0)

# %%
titanic_ds[['fg_Embark_S','Embarked']]
# Out:
#      fg_Embark_S Embarked
# 0              1        S
# 1              0        C
# 2              1        S
# 3              1        S
# 4              1        S
# 5              0        Q
# 6              1        S
# 7              1        S
# 8              1        S
# 9              0        C
# 10             1        S
# 11             1        S
# 12             1        S
# 13             1        S
# 14             1        S
# 15             1        S
# 16             0        Q
# 17             1        S
# 18             1        S
# 19             0        C
# 20             1        S
# 21             1        S
# 22             0        Q
# 23             1        S
# 24             1        S
# 25             1        S
# 26             0        C
# 27             1        S
# 28             0        Q
# 29             1        S
# ..           ...      ...
# 861            1        S
# 862            1        S
# 863            1        S
# ...

# %%
titanic_ds['fg_Embark_C']=np.where(titanic_ds['Embarked'] == 'C',1,0)

# %%
titanic_ds[['fg_Embark_C','Embarked']]
# Out:
#      fg_Embark_C Embarked
# 0              0        S
# 1              1        C
# 2              0        S
# 3              0        S
# 4              0        S
# 5              0        Q
# 6              0        S
# 7              0        S
# 8              0        S
# 9              1        C
# 10             0        S
# 11             0        S
# 12             0        S
# 13             0        S
# 14             0        S
# 15             0        S
# 16             0        Q
# 17             0        S
# 18             0        S
# 19             1        C
# 20             0        S
# 21             0        S
# 22             0        Q
# 23             0        S
# 24             0        S
# 25             0        S
# 26             1        C
# 27             0        S
# 28             0        Q
# 29             0        S
# ..           ...      ...
# 861            0        S
# 862            0        S
# 863            0        S
# ...

# %%
titanic_ds['SibSp']=np.where(titanic_ds.SibSp.isin([2,3,4,5,8]),2,titanic_ds['SibSp'])

# %%
titanic_ds['Parch']=np.where(titanic_ds.Parch.isin([2,3,4,5,6]),2,titanic_ds['Parch'])

# %%
import variance_inflation_factor
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-56-21f022f053ad> in <module>()
# ----> 1 import variance_inflation_factor
#
# ModuleNotFoundError: No module named 'variance_inflation_factor'

# %%
titanic_ds.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# is_Cabin         int32
# fg_Pclass_1      int32
# fg_Pclass_2      int32
# fg_Sex_M         int32
# fg_Embark_S      int32
# fg_Embark_C      int32
# dtype: object

# %%
titanic_ds=titanic_ds.drop(columns=['Embarked','Sex','Pclass','Cabin','Name','Ticket','PassengerId'])

# %%
titanic_ds.dtypes
# Out:
# Survived         int64
# Age            float64
# SibSp            int64
# Parch            int64
# Fare           float64
# is_Cabin         int32
# fg_Pclass_1      int32
# fg_Pclass_2      int32
# fg_Sex_M         int32
# fg_Embark_S      int32
# fg_Embark_C      int32
# dtype: object

# %%
X=titanic_ds.loc[:, titanic_ds.columns != 'Survived']
y = titanic_ds.loc[:, titanic_ds.columns == 'Survived']

# %%
X.dtypes
# Out:
# Age            float64
# SibSp            int64
# Parch            int64
# Fare           float64
# is_Cabin         int32
# fg_Pclass_1      int32
# fg_Pclass_2      int32
# fg_Sex_M         int32
# fg_Embark_S      int32
# fg_Embark_C      int32
# dtype: object

# %%
y.dtypes
# Out:
# Survived    int64
# dtype: object

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
rfe = RFE(logreg, 8)
rfe = rfe.fit(X, y.values.ravel())
print(rfe.support_)
print(rfe.ranking_)
# Out:
# [False  True  True False  True  True  True  True  True  True]
# [2 1 1 3 1 1 1 1 1 1]

# %%
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
def multicollinearity_check(X, thresh=5.0):
    data_type = X.dtypes
    # print(type(data_type))
    int_cols = \
    X.select_dtypes(include=['int', 'int16', 'int32', 'int64', 'float', 'float16', 'float32', 'float64']).shape[1]
    total_cols = X.shape[1]
    try:
        if int_cols != total_cols:
            raise Exception('All the columns should be integer or float, for multicollinearity test.')
        else:
            variables = list(range(X.shape[1]))
            dropped = True
            print('''\n\nThe VIF calculator will now iterate through the features and calculate their respective values.
            It shall continue dropping the highest VIF features until all the features have VIF less than the threshold of 5.\n\n''')
            while dropped:
                dropped = False
                vif = [variance_inflation_factor(X.iloc[:, variables].values, ix) for ix in variables]
                print('\n\nvif is: ', vif)
                maxloc = vif.index(max(vif))
                if max(vif) > thresh:
                    print('dropping \'' + X.iloc[:, variables].columns[maxloc] + '\' at index: ' + str(maxloc))
                    # del variables[maxloc]
                    X.drop(X.columns[variables[maxloc]], 1, inplace=True)
                    variables = list(range(X.shape[1]))
                    dropped = True

            print('\n\nRemaining variables:\n')
            print(X.columns[variables])
            # return X.iloc[:,variables]
            return X
    except Exception as e:
        print('Error caught: ', e)

# %%
multicollinearity_check(X,5)
# Out:
# The VIF calculator will now iterate through the features and calculate their respective values.
#             It shall continue dropping the highest VIF features until all the features have VIF less than the threshold of 5.
#
#
#
#
# vif is:  [5.470611870606714, 1.7869431129048337, 1.845622900737016, 3.572462836009283, 3.5188629082012093, 5.393425826464684, 1.5011405037992345, 3.010592844332362, 5.918307254205377, 2.3524249547215144]
# dropping 'fg_Embark_S' at index: 8
#
#
# vif is:  [3.8473212995669352, 1.7391241379605333, 1.7294322646705707, 3.5547513540256235, 3.5131585700857553, 5.393413585931057, 1.4107240429270165, 2.417465831234083, 1.3550892970108397]
# dropping 'fg_Pclass_1' at index: 5
#
#
# vif is:  [3.6890457221575876, 1.7286468913830138, 1.6695280207813037, 2.73828348112421, 2.0238415057866916, 1.287268536155542, 2.4140791682945544, 1.3383710063896506]
#
#
# Remaining variables:
#
# Index(['Age', 'SibSp', 'Parch', 'Fare', 'is_Cabin', 'fg_Pclass_2', 'fg_Sex_M',
# ...

# %%
import statsmodels.api as sm
logit_model=sm.Logit(y,X)
result=logit_model.fit()
print(result.summary2())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.452258
#          Iterations 6
#                         Results: Logit
# ...
# Model:              Logit            No. Iterations:   6.0000
# Dependent Variable: Survived         Pseudo R-squared: 0.321
# Date:               2019-06-13 20:45 AIC:              825.9244
# No. Observations:   891              BIC:              873.8478
# Df Model:           9                Log-Likelihood:   -402.96
# Df Residuals:       881              LL-Null:          -593.33
# Converged:          1.0000           Scale:            1.0000
# ---------------------------------------------------------------
#                 Coef.  Std.Err.    z     P>|z|   [0.025  0.975]
# ---------------------------------------------------------------
# Age            -0.0168   0.0063  -2.6566 0.0079 -0.0292 -0.0044
# SibSp          -0.1350   0.1545  -0.8740 0.3821 -0.4378  0.1678
# Parch          -0.0660   0.1518  -0.4347 0.6638 -0.3634  0.2315
# ...

# %%
cols=['is_Cabin','fg_Pclass_2','fg_Sex_M','fg_Embark_C']

# %%
fi_var=X[cols]

# %%
logit_model=sm.Logit(y,fi_var)
result=logit_model.fit()
print(result.summary2())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.462979
#          Iterations 6
#                         Results: Logit
# ...
# Model:              Logit            No. Iterations:   6.0000
# Dependent Variable: Survived         Pseudo R-squared: 0.305
# Date:               2019-06-13 21:07 AIC:              833.0289
# No. Observations:   891              BIC:              852.1982
# Df Model:           3                Log-Likelihood:   -412.51
# Df Residuals:       887              LL-Null:          -593.33
# Converged:          1.0000           Scale:            1.0000
# ---------------------------------------------------------------
#                 Coef.  Std.Err.    z     P>|z|   [0.025  0.975]
# ---------------------------------------------------------------
# is_Cabin        1.8550   0.2046   9.0656 0.0000  1.4540  2.2561
# fg_Pclass_2     1.0685   0.1960   5.4509 0.0000  0.6843  1.4527
# fg_Sex_M       -2.3578   0.1515 -15.5600 0.0000 -2.6548 -2.0608
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
X_train, X_test, y_train, y_test = train_test_split(fi_var, y, test_size=0.3, random_state=0)
logreg = LogisticRegression()
logreg.fit(X_train, y_train)
# Out:
# C:\Users\ABHI\Anaconda3\lib\site-packages\sklearn\utils\validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
y_pred = logreg.predict(X_test)
print('Accuracy of logistic regression classifier on test set: {:.2f}'.format(logreg.score(X_test, y_test)))
# Out:
# Accuracy of logistic regression classifier on test set: 0.80

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y_test, y_pred)
print(confusion_matrix)
# Out:
# [[136  32]
#  [ 21  79]]

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.87      0.81      0.84       168
#           1       0.71      0.79      0.75       100
#
# avg / total       0.81      0.80      0.80       268

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt 
logit_roc_auc = roc_auc_score(y_test, logreg.predict(X_test))
fpr, tpr, thresholds = roc_curve(y_test, logreg.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('Log_ROC')
plt.show()
